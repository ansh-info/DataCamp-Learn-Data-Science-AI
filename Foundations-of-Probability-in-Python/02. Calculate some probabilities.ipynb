# %% [markdown]
# 1\. Calculating probabilities of two events
# -------------------------------------------
#
# 00:00 - 00:05
#
# In this lesson, you will learn how to calculate the probability of two events.
#
# 2\. Independence
# ----------------
#
# 00:05 - 00:19
#
# Given two events, if the events are not affected by the order in which they happen and the occurrence of one event does not affect the probability of the other, then the events are independent.
#
# Given that A and B are events in a random experiment, the conditions for independence of Aand B are:
#
# 1. The order in which A and B occur does not affect their probabilities.
# 2. If A occurs, this does not affect the probability of B.
# 3. If B occurs, this does not affect the probability of A.
#
#
# 3\. Probability of A and B for independent events
# -------------------------------------------------
#
# 00:19 - 00:22
#
# Let's work with a fair coin.
#
# Fair coin
#
# P(🪙) = 0.5
#
# P(🪙) = 0.5
#
#
# 4\. Two coin flips
# ------------------
#
# 00:22 - 00:27
#
# If we flip a coin twice, we get four possible outcomes.
#
# First      Second     Outcome
#
# 🪙         🪙         🪙🪙
# 🪙         👤         🪙👤
# 👤         🪙         👤🪙
# 👤         👤         👤👤
#
#
# 5\. Two coin flips (Cont.)
# --------------------------
#
# 00:27 - 00:30
#
# We can ask what the probability of each outcome is.
#
#
# First      Second     Outcome         Probability
#
# 🪙         🪙         🪙🪙         P(🪙 and 🪙) = ?
# 🪙         👤         🪙👤         P(🪙 and 👤) = ?
# 👤         🪙         👤🪙         P(👤 and 🪙) = ?
# 👤         👤         👤👤         P(👤 and 👤) = ?
#
#
# 6\. Two coin flips (Cont.)
# --------------------------
#
# 00:30 - 00:35
#
# For independent events, we use the multiplication rule.
#
# P(🪙 and 🪙) = ?
#
# P(🪙 and 👤) = ?
#
# P(👤 and 🪙) = ?
#
# P(👤 and 👤) = ?
#
#
# 7\. Two coin flips (Cont.)
# --------------------------
#
# 00:35 - 00:38
#
# The probability of A and B...
#
# P(A and B) = P(A) P(B)
#
# P(🪙 and 🪙) = ?
#
# P(🪙 and 👤) = ?
#
# P(👤 and 🪙) = ?
#
# P(👤 and 👤) = ?
#
#
# 8\. Two coin flips (Cont.)
# --------------------------
#
# 00:38 - 00:43
#
# is the probability of A times the probability of B.
#
# P(A and B) = P(A) P(B)
#
# P(🪙 and 🪙) = P(🪙) P(🪙)
#
# P(🪙 and 👤) = P(🪙) P(👤)
#
# P(👤 and 🪙) = P(👤) P(🪙)
#
# P(👤 and 👤) = P(👤) P(👤)
#
#
# 9\. Two coin flips (Cont.)
# --------------------------
#
# 00:43 - 00:48
#
# For instance, we get 0.25 for two tails.
#
# P(A and B) = P(A) P(B)
#
# P(🪙 and 🪙) = P(🪙) P(🪙) = (0.5)(0.5) = 0.25
#
# P(🪙 and 👤) = P(🪙) P(👤) = (0.5)(0.5) = 0.25
#
# P(👤 and 🪙) = P(👤) P(🪙) = (0.5)(0.5) = 0.25
#
# P(👤 and 👤) = P(👤) P(👤) = (0.5)(0.5) = 0.25

# %% [markdown]
# 10\. Measuring a sample
# -----------------------
#
# 00:48 - 01:25
#
# Generating a sample of two fair coin flips, we get the number of heads for each throw. We can count how many times each outcome repeats using the function find_repeats. To use find_repeats, you must import it from scipy dot stats. You pass the data to the function to get how many times each outcome in the data repeats. You can see in the counts array that 2 tails repeats 249 times in the 1,000 throws.
#
# ```python
# from scipy.stats import binom
# sample = binom.rvs(n=2, p=0.5, size=1000, random_state=1)
# ```
#
# ```python
# array([1, 1, 0, 1, 0, 0, 0, 1, 1, 1, 1, 0, 2, 0, 1, 1, 1, 0, 0, 2, 2, ...])
# ```
#
# ```python
# from scipy.stats import find_repeats
# find_repeats(sample)
# ```
#
# ```python
# RepeatedResults(values=array([0., 1., 2.]), counts=array([249, 497, 254]))
# ```
#
# 11\. Two coin flips
# -------------------
#
# 01:25 - 01:31
#
# Using a biased coin with 80% probability of heads...
#
# _Unfair coin_
#
# P(🪙) = 0.2
#
# P(👤) = 0.8
#
#
# 12\. Two coin flips (Cont.)
# ---------------------------
#
# 01:31 - 01:34
#
# we see that there is a 4% chance of getting two tails.
#
# P(A and B) = P(A) P(B)
#
# P(🪙 and 🪙) = P(🪙) P(🪙) = (0.2)(0.2) = 0.04
#
# P(🪙 and 👤) = P(🪙) P(👤) = (0.2)(0.8) = 0.16
#
# P(👤 and 🪙) = P(👤) P(🪙) = (0.8)(0.2) = 0.16
#
# P(👤 and 👤) = P(👤) P(👤) = (0.8)(0.8) = 0.64

# %% [markdown]
# 10\. Measuring a sample
# -----------------------
#
# 00:48 - 01:25
#
# Generating a sample of two fair coin flips, we get the number of heads for each throw. We can count how many times each outcome repeats using the function find_repeats. To use find_repeats, you must import it from scipy dot stats. You pass the data to the function to get how many times each outcome in the data repeats. You can see in the counts array that 2 tails repeats 249 times in the 1,000 throws.
#
# ```python
# from scipy.stats import binom
# sample = binom.rvs(n=2, p=0.5, size=1000, random_state=1)
# ```
#
# ```python
# array([1, 1, 0, 1, 0, 0, 0, 1, 1, 1, 1, 0, 2, 0, 1, 1, 1, 0, 0, 2, 2, ...])
# ```
#
# ```python
# from scipy.stats import find_repeats
# find_repeats(sample)
# ```
#
# ```python
# RepeatedResults(values=array([0., 1., 2.]), counts=array([249, 497, 254]))
# ```
#
# 11\. Two coin flips
# -------------------
#
# 01:25 - 01:31
#
# Using a biased coin with 80% probability of heads...
#
# _Unfair coin_
#
# P(🪙) = 0.2
#
# P(👤) = 0.8
#
#
# 12\. Two coin flips (Cont.)
# ---------------------------
#
# 01:31 - 01:34
#
# we see that there is a 4% chance of getting two tails.
#
# P(A and B) = P(A) P(B)
#
# P(🪙 and 🪙) = P(🪙) P(🪙) = (0.2)(0.2) = 0.04
#
# P(🪙 and 👤) = P(🪙) P(👤) = (0.2)(0.8) = 0.16
#
# P(👤 and 🪙) = P(👤) P(🪙) = (0.8)(0.2) = 0.16
#
# P(👤 and 👤) = P(👤) P(👤) = (0.8)(0.8) = 0.64

# %% [markdown]
# 13\. Measuring a biased sample
# ------------------------------
#
# 01:34 - 02:16
#
# The relative frequency is the number of favorable trials divided by the total trials. To get the relative frequency from data, you can import the scipy dot stats dot relfreq function and specify the data and numbins as parameters. In our case, numbins is 3 for the three possible outcomes of two tails, one heads and one tails, or two heads. In the frequency array the relative frequency of 0 (two tails) is almost 4%.
#
# ```python
# from scipy.stats import relfreq
# relfreq(biased_sample, numbins=3).frequency
# ```
#
# ```python
# array([0.039, 0.317, 0.644])
# ```
#
# 14\. Joint probability calculation
# ----------------------------------
#
# 02:16 - 02:48
#
# Moving on to a different example, we are provided with the probability of failure for an engine and a gear box. What is the probability of both failing? The probability of failure for the engine is 1% and for the gear box it's 0.5%, assuming independence. We multiply the two probabilities to get 0.00005. Now let's work with the probability of A or B.
#
# ```python
# P_Eng_fail = 0.01
# P_GearB_fail = 0.005
# P_both_fails = P_Eng_fail * P_GearB_fail
# print(P_both_fails)
# ```
#
# ```python
# 0.00005
# ```
#
# 15\. P(A or B) with cards
# -------------------------
#
# 02:48 - 02:57
#
# Consider a deck of cards. Calculate the probability of getting a Jack or a King.
#
#
# P(Jack or King) = 8 / 52 = 0.1538
#
#
# 16\. P(A or B) with cards (Cont.)
# ---------------------------------
#
# 02:57 - 03:06
#
# We add the probability of getting a Jack, 4 divided by 52...
#
# P(Jack or King) = P(Jack) + ...
#
# P(Jack or King) = 4/52 + ...
#
#
# 17\. P(A or B) with cards (Cont.)
# ---------------------------------
#
# 03:06 - 03:17
#
# with the probability of getting a King, which is the same. There is no overlap between those two events. This means there are no common elements in drawing a King or a Jack.
#
# P(Jack or King) = P(Jack) + P(King)
#
# P(Jack or King) = 4/52 + 4/52
#
#
# 18\. P(A or B) with cards (Cont.)
# ---------------------------------
#
# 03:17 - 03:25
#
# After some calculation, we see that the probability of drawing either a Jack or a King is 2 over 13.
#
# P(Jack or King) = P(Jack) + P(King)
#
# P(Jack or King) = 4/52 + 4/52 = 8/52 = 2/13
#
#
# 19\. P(A or B) with cards (Cont.)
# ---------------------------------
#
# 03:25 - 03:30
#
# Visually, you can see the result of such a probability.
#
# P(Jack or King) = P(Jack) + P(King)
#
# P(Jack or King) = 4/52 + 4/52 = 8/52 = 2/13
#
#
# 20\. Probability of A or B
# --------------------------
#
# 03:30 - 03:37
#
# To calculate the probability of A or B more generally, let's consider an event A...
#
# [A]
#
# 21\. Probability of A or B (Cont.)
# ----------------------------------
#
# 03:37 - 03:46
#
# and an event B without overlap with A. That means there are no common elements in the events.
#
# [A][B]
#
# 22\. Probability of A or B (Cont.)
# ----------------------------------
#
# 03:46 - 03:49
#
# The probability of A or B...
#
# P(A or B) = ?
#
# [A][B]
#
# 23\. Probability of A or B (Cont.)
# ----------------------------------
#
# 03:49 - 03:51
#
# is the probability of A...
#
# P(A or B) = P(A) + ...
#
# [A][B]
#
# 24\. Probability of A or B (Cont.)
# ----------------------------------
#
# 03:51 - 03:56
#
# plus the probability of B. In this sense, the probability is additive.
#
# P(A or B) = P(A) + P(B)
#
# [A][B]
#
# 25\. P(A or B) with overlap
# ---------------------------
#
# 03:56 - 04:07
#
# For overlapping events, such as the probability of drawing a Jack and a heart, the procedure is slightly different.
#
# P(Jack or Heart) = ?
#
# 26\. P(A or B) with overlap (Cont.)
# -----------------------------------
#
# 04:07 - 04:10
#
# We add the probability of getting a Jack, which is 4 divided by 52...
#
# P(Jack or Heart) = P(Jack) + ...
#
# P(Jack or Heart) = 4/52 ...
#
#
# 27\. P(A or B) with overlap (Cont.)
# -----------------------------------
#
# 04:10 - 04:17
#
# with the probability of getting a heart, which is 13 divided by 52...
#
# P(Jack or Heart) = P(Jack) + P(Heart) ...
#
# P(Jack or Heart) = + ... 4/52 + 13/52 ...
#
#
# 28\. P(A or B) with overlap (Cont.)
# -----------------------------------
#
# 04:17 - 04:19
#
# and we subtract the overlap.
#
# 29\. P(A or B) with overlap (Cont.)
# -----------------------------------
#
# 04:19 - 04:28
#
# This is the probability of getting both a Jack and a heart, which is 1 over 52.
#
# P(Jack or Heart) = P(Jack) + P(Heart) ...
#
# P(Jack or Heart) = 4/52 + 13/52 ...
#
# 30\. P(A or B) with overlap (Cont.)
# -----------------------------------
#
# 04:28 - 04:32
#
# The result is 4 divided by 13.
#
# P(Jack or Heart) = P(Jack) + P(heart) -P(jack and Heart)
#
# P(Jack or Heart) = 4/52 = 13/52 - 1/52
#
# 31\. Diagram of P(A or B)
# -------------------------
#
# 04:32 - 04:37
#
# More generally, let's consider an event A...
#
# P(Jack or Heart) = P(jack) + P(Heart) - P(Jack and Heart)
#
# P(Jack or Heart) = 4/52 + 13/52 - 1/52 = 16/52 = 4/13
#
# 32\. Diagram of P(A or B) (Cont.)
# ---------------------------------
#
# 04:37 - 04:39
#
# and an event B which overlaps with A.
#
# [A]
#
# 33\. Diagram of P(A or B) (Cont.)
# ---------------------------------
#
# 04:39 - 04:43
#
# The probability of A or B...
#
# [A][B]
#
# 34\. Diagram of P(A or B) (Cont.)
# ---------------------------------
#
# 04:43 - 04:45
#
# is the probability of A...
#
# P(A or B) =?
#
# [A][B]
#
# 35\. Diagram of P(A or B) (Cont.)
# ---------------------------------
#
# 04:45 - 04:49
#
# plus the probability of B.
#
# P(A or B) = P(A) + ...
#
# [A][B]
#
# 36\. Diagram of P(A or B) (Cont.)
# ---------------------------------
#
# 04:49 - 04:51
#
# But we have to subtract the overlap...
#
# P(A or B) = P(A) + P(B) ...
#
# [A][B]
#
# 37\. Diagram of P(A or B) (Cont.)
# ---------------------------------
#
# 04:51 - 04:55
#
# so we subtract the probability of A and B.
#
# P(A or B) = P(A) = P(B) - P(A and B)
#
# [A][B]
#
# 38\. Diagram of P(A or B) (Cont.)
# ---------------------------------
#
# 04:55 - 05:01
#
# That is the formula to calculate the probability of A or B in general.
#
# ```python
# P_Jack = 4/52
# P_Hearts = 13/52
# P_Jack_n_Hearts = 1/52
# P_Jack_or_Hearts = P_Jack + P_Hearts - P_Jack_n_Hearts
# print(P_Jack_or_Hearts)
# ```
#
# ```python
# 0.307692307692
# ```
#
# 39\. P(Jack or Heart) calculation in Python
# -------------------------------------------
#
# 05:01 - 05:22
#
# In Python, you create the variables with the probabilities, add P underscore Jack and P underscore Hearts, subtract P underscore Jack underscore n underscore Hearts, and print the result. The probability of getting a Jack or a heart is 30%.
#
# P(A or B) = P(A) + P(B) - P(A and B)
#
# [A][B]
#
# 40\. Let's calculate probabilities of two events
# ------------------------------------------------
#
# 05:22 - 05:27
#
# Let's calculate the probabilities of two events.

# %% [markdown]
# Any overlap?
# ============
#
# When you calculate probabilities for multiple events the most important thing to notice is the relation between the events, in particular, if there is any overlap between any two events.
#
# -   What would be the formula to calculate the probability of A or B, given that A and B are not mutually exclusive?
#
# ##### Answer the question
#
# #### Possible Answers
#
# Select one answer
#
# [x] -   P(A and B) = P(A) + P(B)
#
#     PRESS1
#
# -   P(A or B) = P(A) - P(B) + P(A and B)
#
#     PRESS2
#
# -   P(A or B) = P(A)P(B) - P(A and B)
#
#     PRESS3
#
# -   P(A or B) = P(A) + P(B) - P(A and B)
#
#     PRESS4

# %% [markdown]
# Measuring a sample
# ==================
#
# Let's work with a sample of coin flips to calculate some probabilities. You will calculate absolute and relative frequency and check the theoretical value from the distribution of the sample data.
#
# The array `sample_of_two_coin_flips` has 1,000 experiments, each consisting of two fair coin flips. For each experiment, we record the number of heads out of the two coin flips: 0, 1, or 2.
#
# We've preloaded the `binom` object and the `find_repeats()` and `relfreq()` methods from the `scipy.stats` library for you. You'll need these to calculate the probabilities in this exercise.
#
# Instructions 1/3
# ----------------
#
# -   From the provided samples in `sample_of_two_coin_flips`, get the probability of having 2 heads out of the 1,000 trials.

# %%
import numpy as np

# Assuming sample_of_two_coin_flips is a NumPy array
count_2_heads = np.sum(sample_of_two_coin_flips == 2)
total_draws = len(sample_of_two_coin_flips)

# Divide the number of heads by the total number of draws
prob_2_heads = count_2_heads / total_draws

# Display the result
print(prob_2_heads)

# %% [markdown]
# Instructions 2/3
# ----------------
#
# -   Calculate the relative frequency from `sample_of_two_coin_flips`, set `numbins` as `3`, and extract `frequency`.

# %%
rel_freq = relfreq(sample_of_two_coin_flips, numbins=3).frequency
print(rel_freq)

# %% [markdown]
# Instructions 3/3
# ----------------
#
# -   Calculate the probability of getting 0, 1, or 2 from a binomial distribution with `n=2` and `p=0.5`.

# %%
# Probability of getting 0, 1, or 2 from the distribution
probabilities = binom.pmf([0, 1, 2], n=2, p=0.5)
print(probabilities)

# %% [markdown]
# Joint probabilities
# ===================
#
# In this exercise we're going to calculate joint probabilities using the following table:
#
#               Engine     Gear box
# Fails         0.01        0.005
# Works         0.99        0.995
#
#
# Take the values from the table, create variables, and calculate the probability of the event in each step.
#
# Instructions 1/3
# ----------------
#
# -   Calculate the probability that the engine and gear box both work.

# %%
# Individual probabilities
P_Eng_works = 0.99
P_GearB_works = 0.995

# Joint probability calculation
P_both_works = P_Eng_works * P_GearB_works

print(P_both_works)

# %% [markdown]
# Instructions 2/3
# ----------------
#
# -   Calculate the probability that one fails -- either engine or gear box -- but not both.

# %%
# Individual probabilities
P_Eng_fails = 0.01
P_Eng_works = 0.99
P_GearB_fails = 0.005
P_GearB_works = 0.995

# Joint probability calculation
P_only_GearB_fails = P_GearB_fails * P_Eng_works
P_only_Eng_fails = P_Eng_fails * P_GearB_works

# Calculate result
P_one_fails = P_only_GearB_fails + P_only_Eng_fails

print(P_one_fails)

# %% [markdown]
# Instructions 3/3
# ----------------
#
# -   What is the probability that either both work or both fail?

# %%
# Individual probabilities
P_Eng_fails = 0.01
P_Eng_works = 0.99
P_GearB_fails = 0.005
P_GearB_works = 0.995

# Joint probability calculation
P_EngW_GearBW = P_Eng_works * P_GearB_works
P_EngF_GearBF = P_Eng_fails * P_GearB_fails

# Calculate result
P_fails_or_works = P_EngW_GearBW + P_EngF_GearBF

print(P_fails_or_works)

# %% [markdown]
# Deck of cards
# =============
#
# In this exercise, you'll use the following deck of cards to calculate some probabilities in each step:
#
#
# -   Calculate the probability of not getting an Ace.

# %%
P_Ace = 4/52


P_not_Ace = 1 - P_Ace

print(P_not_Ace)

# %% [markdown]
# Instructions 2/4
# ----------------
#
# -   Calculate the probability of getting a red card.

# %%
# Figure probabilities
P_Hearts = 13/52
P_Diamonds = 13/52

# Probability of red calculation
P_Red = P_Hearts + P_Diamonds

print(P_Red)

# %% [markdown]
# Instructions 3/4
# ----------------
#
# -   Calculate the probability of getting a Jack or a spade.

# %%
# Figure probabilities
P_Jack = 4/52
P_Spade = 13/52

# Joint probability
P_Jack_n_Spade = 1/52

# Probability of Jack or spade
P_Jack_or_Spade = P_Jack + P_Spade - P_Jack_n_Spade

print(P_Jack_or_Spade)

# %% [markdown]
# Instructions 4/4
# ----------------
#
# -   Calculate the probability of getting a King or a Queen.

# %%
# Figure probabilities
P_King = 4/52
P_Queen = 4/52

# Joint probability
P_King_n_Queen = 0

# Probability of King or Queen
P_King_or_Queen = P_King + P_Queen - P_King_n_Queen

print(P_King_or_Queen)

# %% [markdown]
# 1\. Conditional probabilities
# -----------------------------
#
# 00:00 - 00:12
#
# In the previous lesson we considered independent events to calculate the probability of A and B. Now we will work with dependent events and define conditional probability.
#
# 2\. Dependent events
# --------------------
#
# 00:12 - 00:18
#
# If we consider a deck of cards and we want to calculate the probability of getting a Jack...
#
# 3\. Dependent events (Cont.)
# ----------------------------
#
# 00:18 - 00:26
#
# we can see that it is 7.69%. But if we take a Jack out of the deck...
#
# P(Jack) = 4 / 52 ≃ 7.69%
#
#
# 4\. Dependent events (Cont.)
# ----------------------------
#
# 00:26 - 00:46
#
# then the probability of getting a Jack has changed. Now it's 5.88%. The probability of the second card depends on the first card, and the order in which the cards are drawn affects the outcome, so the events are dependent.
#
# P(Jack) = 3 / 51 ≃ 5.88%
#
# 5\. Conditional probability formula
# -----------------------------------
#
# 00:46 - 01:00
#
# We saw earlier that the probability of A and B follows the multiplication rule. When we work with dependent events the calculation changes, and we have to introduce conditional probability.
#
# P(A and B)=P(A)P(B)
#
# 6\. Conditional probability formula (Cont.)
# -------------------------------------------
#
# 01:00 - 01:32
#
# With dependent events, the probability of A and B is the probability of A times the probability of B given that A occurred. Rearranging the formula, we get that the probability of B given that A occurred is the joint probability of A and B divided by the probability of A. This is to calculate probabilities in a restricted sample space. Let's take a look at an example.
#
# P(A and B) = P(A)P(B | A)
#
# P(B | A) = P(A and B) / P(A)
#
#
#
# 7\. Conditional probability
# ---------------------------
#
# 01:32 - 01:35
#
# In our deck of cards...
#
# 8\. Conditional probability (Cont.)
# -----------------------------------
#
# 01:35 - 01:42
#
# let's calculate the probability of getting a red card given that we know the card is a Jack.
#
# P(Red|Jack) =?
#
# 9\. Conditional probability (Cont.)
# -----------------------------------
#
# 01:42 - 01:46
#
# Using the formula for conditional probability...
#
# P(Red|Jack) = P(Jack and Red)/P(Jack)
#
# 10\. Conditional probability (Cont.)
# ------------------------------------
#
# 01:46 - 01:53
#
# first we reduce our sample space to the event given as a fact, which is that the card is a Jack.
#
# P(Red|Jack) = P(Jack and Red)/P(Jack)
#
# 11\. Conditional probability (Cont.)
# ------------------------------------
#
# 01:53 - 01:57
#
# There are 4 Jacks out of the 52 cards...
#
# P(Red|Jack) = P(Jack and Red)/P(Jack) = X/4/52
#
# 12\. Conditional probability (Cont.)
# ------------------------------------
#
# 01:57 - 02:02
#
# and the numerator is 2 red cards which are also Jacks.
#
# P(Red|Jack) = P(Jack and Red)/P(Jack) = 2/52/4/52
#
# 13\. Conditional probability (Cont.)
# ------------------------------------
#
# 02:02 - 02:10
#
# So we get that the probability of getting a red card given that it's a Jack is 1 over 2, or 50%.
#
# P(Red|Jack) = P(Jack and Red)/P(Jack) = 2/52/4/52 = 2/4 =1/2
#
# 14\. Conditional probability (Cont.)
# ------------------------------------
#
# 02:10 - 02:19
#
# You can see the result visually, reducing the sample space to the Jack cards. We have 1 red card for each 2 cards.
#
# P(Red|Jack) = P(Jack and Red)/P(Jack) = 2/52/4/52 = 2/4 =1/2
#
# 15\. P(Red | Jack) calculation in Python
# ----------------------------------------
#
# 02:19 - 02:39
#
# In Python, we create the variables for the probability of Jack and the probability of Jack and red to use the formula for conditional probability. We divide the joint probability of Jack and red by the probability of Jack to get 0.5 probability.
#
# ```python
# P_Jack = 4/52
# P_Jack_n_Red = 2/52
#
# P_Red_given_Jack = P_Jack_n_Red / P_Jack
#
# print(P_Red_given_Jack)
# ```
#
# ```
# 0.5
# ```
#
# 16\. Conditional probability
# ----------------------------
#
# 02:39 - 02:47
#
# Conversely, what if we want to calculate the probability of getting a Jack given that it is a red card?
#
# P(Jack|Red) =?
#
# 17\. Conditional probability (Cont.)
# ------------------------------------
#
# 02:47 - 02:50
#
# We use the formula again...
#
# P(Jack|Red) = P(Red and Jack)/P(Red)
#
# 18\. Conditional probability (Cont.)
# ------------------------------------
#
# 02:50 - 02:53
#
# reducing our sample space to the red cards...
#
# P(Jack|Red) = P(Red and Jack)/P(Red)
#
# 19\. Conditional probability (Cont.)
# ------------------------------------
#
# 02:53 - 02:56
#
# because the card being red is the given fact.
#
# P(Jack|Red) = P(Red and Jack)/P(Red)
#
# 20\. Conditional probability (Cont.)
# ------------------------------------
#
# 02:56 - 03:01
#
# We have 26 red cards in a deck...
#
# P(Jack|Red) = P(Red and Jack)/P(Red) = X/26/52
#
# 21\. Conditional probability (Cont.)
# ------------------------------------
#
# 03:01 - 03:04
#
# and we have 2 red Jacks out of 52 cards.
#
# P(Jack|Red) = P(Red and Jack)/P(Red) = 2/52/26/52
#
# 22\. Conditional probability (Cont.)
# ------------------------------------
#
# 03:04 - 03:11
#
# Calculating, we get a probability of 1 over 13 of getting a Jack given that the card is red.
#
# P(Jack|Red) = P(Red and Jack)/P(Red) = 2/52/26/52 = 2/26 = 1/13
#
# 23\. Conditional probability (Cont.)
# ------------------------------------
#
# 03:11 - 03:21
#
# We have just reduced our sample space to the red cards, which is the given fact, and recalculated the probabilities.
#
# P(Jack|Red) = P(Red and Jack)/P(Red) = 2/52/26/52 = 2/26 = 1/13
#
# 24\. P(Jack | Red) calculation in Python
# ----------------------------------------
#
# 03:21 - 03:41
#
# In Python, we create the variables for the probability of red and the joint probability of red and Jack to use the formula for conditional probability. Then we divide the joint probability of red and Jack by the probability of red to get a probability of 0.077.
#
# ```python
# P_Red = 26/52
# P_Red_n_Jack = 2/52
#
# P_Jack_given_Red = P_Red_n_Jack / P_Red
#
# print(P_of_Jack_given_Red)
# ```
#
# ```
# 0.0769230769231
# ```
#
# 25\. Let's condition events to calculate probabilities
# ------------------------------------------------------
#
# 03:41 - 04:01
#
# Conditional probabilities allow us to calculate probabilities in a reduced or restricted sample space. Conditioning is just changing our reference to calculate probabilities. Now let's condition some events to calculate probabilities.

# %% [markdown]
# Delayed flights
# ===============
#
# A certain airline offers flights departing to New York on Tuesdays and Fridays, but sometimes the flights are delayed:
#
# |  | Delayed | On time | Total |
# | --- | --- | --- | --- |
# | Tuesday | 24 | 114 | 138 |
# | Friday | 11 | 127 | 138 |
# | Total | 35 | 241 | 276 |
#
# At the bottom of the **Delayed** column you have a total of 35, which means there were 35 delayed flights out of the total of 276 departures in the sample. Of these, 24 were on Tuesday and 11 on Friday.
#
# Given the table, answer the following questions:
#
# Instructions 1/4
# ----------------
#
# -   What is the probability of a flight being on time?

# %%
# Needed quantities
On_time = 241
Total_departures = 276

# Probability calculation
P_On_time = On_time / Total_departures

print(P_On_time)

# %% [markdown]
# Instructions 2/4
# ----------------
#
# -   Every departure is on time with probability `P_On_time`. What is the probability of a flight being delayed?

# %%
# Needed quantities
P_On_time = 241 / 276

# Probability calculation
P_Delayed = 1 - P_On_time

print(P_Delayed)

# %% [markdown]
# Instructions 3/4
# ----------------
#
# -   Given that it's Tuesday, what is the probability of a flight being delayed (`P(Delayed|Tuesday)`)?

# %%
# Needed quantities
Delayed_on_Tuesday = 24  # Number of delayed flights on Tuesday
On_Tuesday = 138        # Total number of flights on Tuesday

# Probability calculation
P_Delayed_g_Tuesday = Delayed_on_Tuesday / On_Tuesday

print(P_Delayed_g_Tuesday)

# %% [markdown]
# Instructions 4/4
# ----------------
#
# -   Given that it's Friday, what is the probability of a flight being delayed (`P(Delayed|Friday)`)?

# %%
# Needed quantities
Delayed_on_Friday = 11
On_Friday = 138

# Probability calculation
P_Delayed_g_Friday = Delayed_on_Friday / On_Friday

print(P_Delayed_g_Friday)

# %% [markdown]
# Contingency table
# =================
#
# The following table shows the numbers of red and black cards in a deck that are Aces and non-Aces:
#
# |  | Red | Black | Total |
# | --- | --- | --- | --- |
# | Ace | 2 | 2 | 4 |
# | Non Ace | 24 | 24 | 48 |
# | Total | 26 | 26 | 52 |
#
# The total in the **Red** column is 26, which means there are 26 red cards in the deck. Of these, 2 are Aces and 24 are non-Aces. There are 52 cards in a deck. Use the values in the table to calculate some conditional probabilities.
#
# Instructions 1/4
# ----------------
#
# -   Calculate `P(Ace|Red)`.

# %%
# Individual probabilities
P_Red = 26/52
P_Red_n_Ace = 2/52

# Conditional probability calculation
P_Ace_given_Red = P_Red_n_Ace / P_Red

print(P_Ace_given_Red)

# %% [markdown]
# Instructions 2/4
# ----------------
#
# -   Calculate `P(Black|Ace)`.

# %%
# Individual probabilities
P_Ace = 4/52
P_Ace_n_Black = 2/52

# Conditional probability calculation
P_Black_given_Ace = P_Ace_n_Black / P_Ace

print(P_Black_given_Ace)

# %% [markdown]
# Instructions 3/4
# ----------------
#
# -   Calculate `P(Non Ace|Black)`.

# %%
# Individual probabilities
P_Black = 26/52
P_Black_n_Non_ace = 24/52

# Conditional probability calculation
P_Non_ace_given_Black = P_Black_n_Non_ace / P_Black

print(P_Non_ace_given_Black)

# %% [markdown]
# Instructions 4/4
# ----------------
#
# -   Calculate `P(Red|Non Ace)`.

# %%
# Individual probabilities
P_Non_ace = 48/52
P_Non_ace_n_Red = 24/52

# Conditional probability calculation
P_Red_given_Non_ace = P_Non_ace_n_Red / P_Non_ace

print(P_Red_given_Non_ace)

# %% [markdown]
# More cards
# ==========
#
# Now let's use the deck of cards to calculate some conditional probabilities.
#
# Instructions 1/3
# ----------------
#
# -   Calculate the probability of getting two Jacks (`P(Jack and Jack)`).

# %%
# Needed probabilities
P_first_Jack = 4/52
P_Jack_given_Jack = 3/51

# Joint probability calculation
P_two_Jacks = P_first_Jack * P_Jack_given_Jack

print(P_two_Jacks)

# %% [markdown]
# Instructions 2/3
# ----------------
#
# -   Calculate `P(Ace|Spade)`.

# %%
# Needed probabilities
P_Spade = 13/52
P_Spade_n_Ace = 1/52

# Conditional probability calculation
P_Ace_given_Spade = P_Spade_n_Ace / P_Spade

print(P_Ace_given_Spade)

# %% [markdown]
# Instructions 3/3
# ----------------
#
# -   Calculate `P(Queen|Face card)`.

# %%
# Needed probabilities
P_Face_card = 12/52
P_Face_card_n_Queen = 4/52

# Conditional probability calculation
P_Queen_given_Face_card = P_Face_card_n_Queen / P_Face_card

print(P_Queen_given_Face_card)

# %% [markdown]
# 1\. Total probability law
# -------------------------
#
# 00:00 - 00:17
#
# Often you can find problems where your sample space, or in other words your possible outcomes, can be broken into non overlapping parts. The total probability law allows you to calculate probabilities under such conditions.
#
# 2\. Deck of cards example
# -------------------------
#
# 00:17 - 00:24
#
# Let's consider a deck of cards, which is naturally partitioned, and the partitions do not overlap.
#
# 3\. Deck of cards example (Cont.)
# ---------------------------------
#
# 00:24 - 00:31
#
# A face card is a card that does not have a number. To get the probability of getting a face card...
#
# P(Face card) =?
#
# 4\. Deck of cards example (Cont.)
# ---------------------------------
#
# 00:31 - 00:40
#
# we just add the probability of getting such a card in each suit. That is, we add the joint probability of getting a club and a face card...
#
# P(Face card) = P(Club and Face card) + ...
#
# 5\. Deck of cards example (Cont.)
# ---------------------------------
#
# 00:40 - 00:45
#
# with the joint probability of getting a spade and a face card...
#
# P(Face card) = P(Club and Face card) + P(Spade and Face card) + ...
#
# 6\. Deck of cards example (Cont.)
# ---------------------------------
#
# 00:45 - 00:49
#
# plus the joint probability of getting a heart and a face card...
#
# P(Face card) = P(Club and Face card) + P(Spade and Face card) + P(Heart and Face card) + ...
#
# 7\. Deck of cards example (Cont.)
# ---------------------------------
#
# 00:49 - 01:01
#
# plus the joint probability of getting a diamond and a face card. We've just added each non overlapping part. Now let's do it in Python.
#
# P(Face card) = P(Club and Face card) + P(Spade and Face card) + P(Heart and Face card) + P(Diamond and Face card)
#
# 8\. Face card example in Python
# -------------------------------
#
# 01:01 - 01:28
#
# In Python, we create the variables that represent the probability of a face card in each suit (clubs, spades, hearts, diamonds), which in each case is 3 over 52. Then, the probability of getting a face card is the sum of all the probabilities, or 23%. Now let's see this problem in general.
#
# ```python
# P_Club_n_FC = 3/52
# P_Spade_n_FC = 3/52
# P_Heart_n_FC = 3/52
# P_Diamond_n_FC = 3/52
#
# P_Face_card = P_Club_n_FC + P_Spade_n_FC + P_Heart_n_FC + P_Diamond_n_FC
# print(P_Face_card)
# ```
#
# ```
# 0.230769230769
# ```
#
# 9\. Total probability
# ---------------------
#
# 01:28 - 01:38
#
# Going back to our vendors and parts example, let's consider all the parts we've bought from different vendors (V1, V2, and V3)...
#
# P []
#
# 10\. Total probability (Cont.)
# ------------------------------
#
# 01:38 - 01:42
#
# and also consider the damaged parts we got.
#
# p [D []]
#
# 11\. Total probability (Cont.)
# ------------------------------
#
# 01:42 - 01:53
#
# We can partition the parts according to the vendor that provided them, and we want to calculate the probability of getting a damaged part.
#
# P(D) =?
#
# 12\. Total probability (Cont.)
# ------------------------------
#
# 01:53 - 01:59
#
# To calculate such a probability, we add the probability of getting a part from V1 that is damaged...
#
# P(D) = P(V1 and D) + ...
#
# 13\. Total probability (Cont.)
# ------------------------------
#
# 01:59 - 02:04
#
# with the probability of getting a part from V2 that is damaged...
#
# P(D) = P(V1 and D) + P(V2 and D) + ...
#
# 14\. Total probability (Cont.)
# ------------------------------
#
# 02:04 - 02:22
#
# and the probability of getting a part from V3 that is damaged. The total probability law states that the probability of an event in a non overlapping partitioned space is the sum of the probabilities of such an event in each partition.
#
# P(D) = P(V1 and D) + P(V2 and D) + P(V3 and D)
#
# 15\. Total probability (Cont.)
# ------------------------------
#
# 02:22 - 03:07
#
# Using the formula for conditional probability, we can get the probability of a part being damaged by calculating the sum of the products of the probability of a part being from V1, V2, or V3 and the probability of a part being damaged given that the part is from V1, V2, or V3. This last formula is very important, so give it some thought. Now let's apply the total probability law with an example.
#
# P(D) = P(V1)P(D|V1) + P(V2)P(D|V2) + P(V3)P(D|V3)
#
# 16\. Damaged parts example in Python
# ------------------------------------
#
# 03:07 - 03:38
#
# A certain electronic part is manufactured by three different vendors, V1, V2, and V3. Half of the parts are produced by V1, and V2 and V3 each produce 25%. The probability of a part being damaged given that it was produced by V1 is 1%, while it's 2% for V2 and 3% for V3. What is the probability of a part being damaged?
#
# A certain electronic part is manufactured by three different vendors, V1, V2, and V3.
#
# Half of the parts are produced by V1, and V2 and V3 each produce 25%. The probability of apart being damaged given that it was produced by V1 is 1%, while it's 2% for V2 and 3% for V3.
#
# - What is the probability of a part being damaged?
#
#
# 17\. Damaged parts example in Python (Cont.)
# --------------------------------------------
#
# 03:38 - 04:08
#
# First we create variables to specify the individual probabilities of a part being from vendors V1, V2, and V3, which are 50%, 25%, and 25%, respectively. Then we create variables to specify the conditional probabilities of receiving a part that is damaged from V1, V2, and V3, which are 1%, 2%, and 3%, respectively.
#
# - What is the probability of a part being damaged?
#
# ```python
# P_V1 = 0.5
# P_V2 = 0.25
# P_V3 = 0.25
#
# P_D_g_V1 = 0.01
# P_D_g_V2 = 0.02
# P_D_g_V3 = 0.03
# ```
#
# 18\. Damaged parts example in Python (Cont.)
# --------------------------------------------
#
# 04:08 - 04:21
#
# Finally, we apply the total probability formula to determine that the probability of getting a part that is damaged is 0.0175.
#
# We apply the total probability formula
#
# ```python
# P_Damaged = P_V1 * P_D_g_V1 + P_V2 * P_D_g_V2 + P_V3 * P_D_g_V3
# print(P_Damaged)
# ```
#
# The probability of being damaged is:
#
# ```
# 0.0175
# ```
#
# 19\. Let's start using the total probability law
# ------------------------------------------------
#
# 04:21 - 04:37
#
# Now you know that if you have non overlapping partitions in your sample space, you can apply the total probability law to calculate probabilities. Let's start using the total probability law.

# %% [markdown]
# Formula 1 engines
# =================
#
# Suppose that two manufacturers, A and B, supply the engines for Formula 1 racing cars, with the following characteristics:
#
# -   99% of the engines from factory A last more than 5,000 km.
# -   Factory B manufactures engines that last more than 5,000 km with 95% probability.
# -   70% of the engines are from manufacturer A, and the rest are produced by manufacturer B.
#
# What is the chance that an engine will last more than 5,000 km?
#
# Instructions
# ------------
#
# -   Calculate the following probabilities:
#     -   The manufacturer is A (`P_A`).
#     -   The engine lasts more than 5,000 km given that manufacturer is A (`P_last5000_g_A`).
#     -   The manufacturer is B (`P_B`).
#     -   The engine lasts more than 5,000 km given that manufacturer is B (`P_last5000_g_B`).
# -   Use the total probability law to calculate the probability that the engine will last more than 5,000 km and store the result into `P_last_5000`.

# %%
# Needed probabilities
P_A = 0.7
P_last5000_g_A = .99
P_B = 0.3
P_last5000_g_B = .95

# Total probability calculation
P_last_5000 = P_A * P_last5000_g_A + P_B * P_last5000_g_B

print(P_last_5000)

# %% [markdown]
# Voters
# ======
#
# Of the total population of three states X, Y, and Z, 43% are from state X, 25% are from state Y, and 32% are from state Z. A poll is taken and the result is the following:
#
# -   53% of the voters support John Doe in state X.
# -   67% of the voters support John Doe in state Y.
# -   32% of the voters support John Doe in state Z.
#
# Given that a voter supports John Doe, answer the following questions.
#
# Instructions 1/3
# ----------------
#
# -   What is the probability that the voter lives in state X and supports John Doe?

# %%
# Individual probabilities
P_X = .43

# Conditional probabilities
P_Support_g_X = .53

# Total probability calculation
P_X_n_Support = P_Support_g_X * P_X
print(P_X_n_Support)

# %% [markdown]
# Instructions 2/3
# ----------------
#
# -   What is the probability that the voter lives in state Z and **does not** support John Doe?

# %%
# Individual probabilities
P_Z = .32

# Conditional probabilities
P_Support_g_Z = 0.32
P_NoSupport_g_Z = 1 - P_Support_g_Z

# Total probability calculation
P_Z_n_NoSupport = P_Z * P_NoSupport_g_Z
print(P_Z_n_NoSupport)

# %% [markdown]
# Instructions 3/3
# ----------------
#
# -   What is the total percentage of voters that support John Doe?

# %%
# Individual probabilities
P_X = .43
P_Y = .25
P_Z = .32

# Conditional probabilities
P_Support_g_X = .53
P_Support_g_Y = .67
P_Support_g_Z = .32


# Total probability calculation
P_Support = P_X * P_Support_g_X + P_Y * P_Support_g_Y + P_Z * P_Support_g_Z
print(P_Support)
