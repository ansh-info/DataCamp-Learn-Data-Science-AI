# %% [markdown]
# 1\. Custom instructions
# -----------------------
#
# 00:00 - 00:01
#
# Welcome back!
#
# 2\. Introduction to custom instructions
# ---------------------------------------
#
# 00:01 - 00:18
#
# Having to start each conversation with ChatGPT from scratch is a lot of friction. Different personas have different needs: an 8th-grade math teacher, a writer crafting their next book, or a programming aficionado. Each requires unique interactions with ChatGPT.
#
# 3\. Introduction to custom instructions
# ---------------------------------------
#
# 00:18 - 00:26
#
# What if ChatGPT could become a personalized assistant that knows who you are, what you do, and how you like to be responded to?
#
# 4\. Introduction to custom instructions
# ---------------------------------------
#
# 00:26 - 00:30
#
# Custom instructions do exactly that.
#
# 5\. Example: Without custom instructions
# ----------------------------------------
#
# 00:30 - 00:49
#
# Let's bring this to life with an example. "I want to write my next piece of content on a concept in AI. What should I consider?" Without custom instructions, here's what ChatGPT proposed: ChatGPT's response is bland and lacks personalization. It doesn't know why 'I' am interested in AI content.
#
# 6\. Example: With custom instructions
# -------------------------------------
#
# 00:49 - 01:09
#
# Here's what ChatGPT suggests after I engaged Custom Instructions: How awesome is this? With custom instructions, ChatGPT suggests personalized writing topics. It understands my interests intersect startups and AI, agentic workflows, and RAG systems.
#
# 7\. Example: With custom instructions
# -------------------------------------
#
# 01:09 - 01:28
#
# But it doesn't just stop there. ChatGPT also highlights inspiration from my favorite writers that I can infuse into the content. This thing is magical. Without Custom Instructions, it's like driving a supercar in first gear. Let's take a look at how you can set up Custom Instructions for yourself.
#
# 8\. Setting up custom instructions
# ----------------------------------
#
# 01:28 - 01:36
#
# Log into ChatGPT and click on your headshot. Then, navigate to "Customize ChatGPT."
#
# 9\. Setting up custom instructions
# ----------------------------------
#
# 01:36 - 01:38
#
# You'll see two boxes.
#
# 10\. Setting up custom instructions
# -----------------------------------
#
# 01:38 - 01:42
#
# "What would you like ChatGPT to know about you to provide better responses?" and...
#
# 11\. Setting up custom instructions
# -----------------------------------
#
# 01:42 - 01:53
#
# "How would you like ChatGPT to respond?". When I saw these two boxes for the first time, I felt overwhelmed and clicked off. There's nothing worse than staring at a blank box.
#
# 12\. Setting up custom instructions
# -----------------------------------
#
# 01:53 - 01:59
#
# But let's break down each of these inputs together so that you have the guiding hand I wish I always had.
#
# 13\. Box 1: About you
# ---------------------
#
# 01:59 - 02:10
#
# First, box number 1. "What would you like ChatGPT to know about you to provide better responses?". Think of this as your 'about' page. Fill it with biographical information.
#
# 14\. Box 1: About you
# ---------------------
#
# 02:10 - 02:36
#
# Here's mine. My name is Alex Banks. I'm a founder, creator, and investor. I write Sunday Signal, a weekly newsletter that combines AI highlights with broader insights that intrigue and inspire. I discuss my writing on LinkedIn and Twitter and highlight who inspires me. I then finish with my personal goals. For me, I want to work on clear communication and become a better listener.
#
# 15\. Box 1: About you (4 A's)
# -----------------------------
#
# 02:36 - 02:43
#
# To help you write yours, use the "4A's": About, Attractions, Aspirations, and Additions.
#
# 16\. Box 1: About you (4 A's)
# -----------------------------
#
# 02:43 - 02:50
#
# If brainstorming is hard, get ChatGPT to summarise your LinkedIn profile or ask a friend for pointers.
#
# 17\. Box 2: Response style
# --------------------------
#
# 02:50 - 02:58
#
# Next is the second box. "How would you like ChatGPT to respond?". Think of this as the voice ChatGPT uses.
#
# 18\. Box 2: Response style
# --------------------------
#
# 02:58 - 03:06
#
# Depending on your response preferences, consider the following tradeoffs for how you'd like ChatGPT to respond:
#
# 19\. Box 2: Response style
# --------------------------
#
# 03:06 - 03:23
#
# ChatGPT can sometimes grind my gears with all the safety talk and moral lectures when I'm hunting for an answer. "I'm not a legal professional," "I'm not a doctor," or "I'm not a financial advisor"... the list goes on. I've found a great way to bypass this is to include the following.
#
# 20\. Box 2: Response style
# --------------------------
#
# 03:23 - 03:28
#
# This was inspired by Jeremy Howard, the co-founder of Fast.ai.
#
# 21\. Box 2: Response style
# --------------------------
#
# 03:28 - 03:42
#
# ChatGPT excels at connecting thoughts across domains for new inspiration. I added: I like connecting my thoughts across domains to find new inspiration. Add a 'Creative link' and 'AI reference' to each response.
#
# 22\. Box 2: Response style example
# ----------------------------------
#
# 03:42 - 04:04
#
# Let's examine this in action. I'll ask ChatGPT about the importance of the drag reduction system on Formula 1 cars. ChatGPT provides a great reference to AI at the end as well as a creative link to pharmaceuticals. It allows you to effortlessly pull on new ideas to spark your creativity.
#
# 23\. Wrap up
# ------------
#
# 04:04 - 04:17
#
# Custom instructions transform your ChatGPT experience. Instead of a prompt that gathers your preferences for just one conversation, custom instructions let you set your preferences for all future conversations, eliminating repetition.
#
# 24\. Let's practice!
# --------------------
#
# 04:17 - 04:28
#
# You can now tailor ChatGPT to better suit your needs. It's time to dive into the exercises where you'll put your newfound Custom Instruction abilities to the test.

# %% [markdown]
# Benefits of custom instructions
# ===============================
#
# Custom instructions can significantly enhance the utility of ChatGPT.
#
# Which of the following is a **primary** benefit of using custom instructions?
#
# ##### Answer the question
#
# #### Possible Answers
#
# Select one answer
#
# -   Custom instructions allow you to reset ChatGPT's responses for each conversation
#
# [x] -   Custom instructions ensure ChatGPT remembers your preferences for all future interactions
#
# -   Custom instructions limit the types of questions you can ask ChatGPT
#
# -   Custom instructions prevent ChatGPT from providing personalized responses

# %% [markdown]
# #### Crafting effective custom instructions
#
# Imagine you're about to start using ChatGPT as your personal AI assistant to help with your work and creative projects. To make ChatGPT as effective as possible, you need to customize it by providing specific instructions that reflect who you are and how you prefer to communicate.
#
# When setting up custom instructions in ChatGPT, it's important to know what to include in each of the two main boxes: "What would you like ChatGPT to know about you to provide better responses?" and "How would you like ChatGPT to respond?".
#
# Have a practice by sorting these example instructions.
#
# ##### Instructions
#
# -   Sort each custom instruction into the appropriate custom instruction box.
# -   Choose between 'What would you like ChatGPT to know about you to provide better responses?' and 'How would you like ChatGPT to respond?'.

# %% [markdown]
# ### What would you like ChatGPT to know about you to provide better responses?
#
# * I am a founder, investor, and creator.
# * My interests include startups, cold water, and hot yoga.
# * I am inspired by Paul Graham, Jeff Bezos, and Howard Marks.
#
# ---
#
# ### How would you like ChatGPT to respond?
#
# * Provide short and concise answers.
# * Discuss safety only when it’s absolutely necessary and not obvious.
# * Consider non-obvious and contrarian answers.

# %% [markdown]
# 1\. Building and deploying custom GPTs
# --------------------------------------
#
# 00:00 - 00:00
#
# Welcome back!
#
# 2\. Custom GPTs
# ---------------
#
# 00:00 - 00:00
#
# While custom instructions let you set some preferences, custom GPTs provide even more flexibility. They act as specialized versions of ChatGPT designed for particular use cases. Some of the best GPTs include: Canva --- Design presentations or social posts Consensus --- Search and synthesize results from 200M academic papers Khan Academy's Code Tutor --- Expand your coding skills
#
# 3\. Custom GPTs
# ---------------
#
# 00:00 - 00:00
#
# And they span the domains of writing, research, programming, education, and lifestyle.
#
# 4\. Example without custom GPTs
# -------------------------------
#
# 00:00 - 00:00
#
# Let's start with an example. "Tell me about the recent advancements in generative AI." ChatGPT provides an overview, but it can be fallible and hallucinate. How can we ensure trustworthiness while accessing real research without trawling through thousands of papers?
#
# 5\. Example using custom GPTs
# -----------------------------
#
# 00:00 - 00:00
#
# Using the Consensus GPT, we can ask the same question: "Tell me about the recent developments in generative AI."
#
# 6\. Example using custom GPTs
# -----------------------------
#
# 00:00 - 00:00
#
# The result is transformed, providing explanations and references to the original papers. Let's dive into how we can build a Custom GPT of our own.
#
# 7\. Building a custom GPT
# -------------------------
#
# 00:00 - 00:00
#
# Log into ChatGPT and click on "Explore GPTs" in the top left corner.
#
# 8\. Building a custom GPT
# -------------------------
#
# 00:00 - 00:00
#
# You're presented with the GPT store. Here, you can find useful and popular GPTs created by others. This is where ours will soon sit. First things first, click 'Create'.
#
# 9\. Building a custom GPT
# -------------------------
#
# 00:00 - 00:00
#
# You'll be presented with two options to build your GPT: "Create" and "Configure." "Create" allows you to simplify the build of your GPT by using natural language. You're conversing with ChatGPT in plain English to determine its instructions and capabilities. The other option, "Configure," provides more control over how you build your GPT. You're able to customize each step with precision. Let's use the "Configure".
#
# 10\. Building a custom GPT: Name
# --------------------------------
#
# 00:00 - 00:00
#
# We'll begin by naming our GPT: AI Insight Bot.
#
# 11\. Building a custom GPT: Knowledge base
# ------------------------------------------
#
# 00:00 - 00:00
#
# We'll upload Stanford University's latest AI Index Report to the custom GPT's knowledge base. This will extend ChatGPT's knowledge and provide up-to-date information.
#
# 12\. Building a custom GPT: Description
# ---------------------------------------
#
# 00:00 - 00:00
#
# Description: Ask questions about the latest trends in AI with Stanford's AI Index Report. We can even add an image to our GPT with DALL-E, ChatGPT's image generation tool.
#
# 13\. Building a custom GPT: Instructions
# ----------------------------------------
#
# 00:00 - 00:00
#
# Instead of creating custom instructions that reside inside our personal account, the instructions we create here are tailored to our AI insight bot.
#
# 14\. Building a custom GPT: Instructions
# ----------------------------------------
#
# 00:00 - 00:00
#
# Remember the PFSET prompt framework we explored in Chapter 2? We're going to condense this to "PFS," just adding the persona, framework, and specifications to our GPT prompt.
#
# 15\. Building a custom GPT: Instructions
# ----------------------------------------
#
# 00:00 - 00:00
#
# Let's set the persona of our AI Insight bot:
#
# 16\. Building a custom GPT: Instructions
# ----------------------------------------
#
# 00:00 - 00:00
#
# Define the framework:
#
# 17\. Building a custom GPT: Instructions
# ----------------------------------------
#
# 00:00 - 00:00
#
# And finally add our specifications for how we want our GPT to respond.
#
# 18\. Building a custom GPT: Instructions
# ----------------------------------------
#
# 00:00 - 00:00
#
# Now, our instructions are set. We've prepared our GPT to provide concise, direct answers. Now let's add some conversation starters.
#
# 19\. Building a custom GPT: Conversation starters
# -------------------------------------------------
#
# 00:00 - 00:00
#
# Conversation starters are a great way to kick off the conversation with our GPT. Think of them as sparks for discussion, igniting our train of thought.
#
# 20\. Building a custom GPT: Capabilities
# ----------------------------------------
#
# 00:00 - 00:00
#
# It's time to upload our report. This will form the foundation of our AI Insight Bot's knowledge base. Finally, we'll turn off "Web browsing" and "DALL-E Image Generation." These tools aren't necessary for the GPT we're creating today and could distract our AI Insight Bot when creating an answer.
#
# 21\. Building a custom GPT: Sharing
# -----------------------------------
#
# 00:00 - 00:00
#
# Now all that's left to do is hit "Create." We can choose to share on the GPT store for public access or save it for private use.
#
# 22\. Building a custom GPT: Testing
# -----------------------------------
#
# 00:00 - 00:00
#
# Let's now put our AI Insight bot to the test. We'll click on the conversation starter we set: "What are the trends in generative AI investment?". Our GPT searches its knowledge base and provides a beautifully succinct and relevant response. It even includes that "AI Fun Fact" we specified in our instructions. Way to go
#
# 23\. Wrap up
# ------------
#
# 00:00 - 00:00
#
# OpenAI has made it easier to build custom GPTs without needing technical skills.
#
# 24\. Wrap up
# ------------
#
# 00:00 - 00:00
#
# As we've explored, you can configure GPTs using the most native thing to humans: natural language.
#
# 25\. Wrap up
# ------------
#
# 00:00 - 00:00
#
# GPTs are great for exploring contexts requiring domain-specific knowledge. Today, we created a custom GPT using an AI industry report.
#
# 26\. Wrap up
# ------------
#
# 00:00 - 00:00
#
# Tomorrow, you could create a custom GPT for company FAQs to help employees with questions like "How many days of holiday do I get this year?" The opportunities are endless.
#
# 27\. Let's practice!
# --------------------
#
# 00:00 - 00:00
#
# It's time to dive into the exercises to put your custom GPT knowledge to the test.

# %% [markdown]
# Custom GPTs versus Custom Instructions
# ======================================
#
# Custom GPTs offer more flexibility than Custom Instructions by allowing users to create specialized versions of ChatGPT for specific use cases.
#
# Which of the following is a key benefit of creating a Custom GPT instead of using Custom Instructions?
#
# ##### Answer the question
#
# #### Possible Answers
#
# Select one answer
#
# -   Custom GPTs can operate without an internet connection
#
# -   Custom GPTs are easier to create than setting Custom Instructions
#
# -   Custom GPTs allow for real-time collaboration with multiple users
#
# [x] -   Custom GPTs provide tailored responses based on specific use cases

# %% [markdown]
# #### Configuring "EcoGuide"
#
# You've just learned about the process of creating and deploying custom GPTs to suit specific needs and contexts.
#
# Imagine you are creating a custom GPT called "EcoGuide" to help users stay informed about sustainable living practices. You plan to upload relevant documents, articles, and guides about eco-friendly habits and green technologies to its knowledge base. Your aim is for "EcoGuide" to provide accurate, practical advice on how users can reduce their environmental footprint.
#
# ##### Instructions
#
# -   Arrange the steps in the correct order to successfully create and configure your custom GPT "EcoGuide".

# %% [markdown]
# 1. Name your GPT **"EcoGuide"** and describe its purpose.
# 2. Upload relevant sustainability reports, articles, and guides to the GPT's knowledge base.
# 3. Configure the GPT to provide actionable and practical advice tailored to the user's needs.
# 4. Add a conversation starter that would help users engage with **"EcoGuide."**
# 5. Create, share, and test the GPT to ensure it functions as expected.

# %% [markdown]
# 1\. The future of ChatGPT
# -------------------------
#
# 00:00 - 00:02
#
# Welcome to the final lesson.
#
# 2\. Recap
# ---------
#
# 00:02 - 00:05
#
# Wow, we've been on quite the adventure.
#
# 3\. Recap
# ---------
#
# 00:05 - 00:08
#
# We started this course by looking at the building blocks of LLMs.
#
# 4\. Recap
# ---------
#
# 00:08 - 00:14
#
# We then explored advanced prompting techniques to get the most out of ChatGPT.
#
# 5\. Recap
# ---------
#
# 00:14 - 00:22
#
# In this final chapter, we've explored the wonders of custom instructions and building our very own custom GPT.
#
# 6\. Recap
# ---------
#
# 00:22 - 00:27
#
# ...which, if you haven't already, you must experiment with on the GPT store.
#
# 7\. The big picture
# -------------------
#
# 00:27 - 00:37
#
# For this final lesson, let's consider the big picture of ChatGPT. Generative AI caught mainstream attention with ChatGPT's launch in November 2022.
#
# 8\. Three key ideas
# -------------------
#
# 00:37 - 00:48
#
# 1\. Why ChatGPT makes mistakes 2. How ChatGPT thinks 3. Where ChatGPT is heading
#
# 9\. Idea 1: Why ChatGPT makes mistakes
# --------------------------------------
#
# 00:48 - 00:51
#
# As we explored in "Understanding Prompt Engineering"
#
# 10\. Idea 1: Why ChatGPT makes mistakes - Reversal curse
# --------------------------------------------------------
#
# 00:51 - 00:58
#
# ChatGPT's knowledge base is imperfect and often quite strange. This is best highlighted by the reversal curse.
#
# 11\. Idea 1: Why ChatGPT makes mistakes - Reversal curse
# --------------------------------------------------------
#
# 00:58 - 01:05
#
# Ask GPT-3.5, "Who is Tom Cruise's mother?" It says Mary Lee Pfeiffer.
#
# 12\. Idea 1: Why ChatGPT makes mistakes - Reversal curse
# --------------------------------------------------------
#
# 01:05 - 01:12
#
# But if you start a new conversation and ask, "Who is Mary Lee Pfeiffer's son?" It says Jeff Bezos! How strange.
#
# 13\. Idea 1: Why ChatGPT makes mistakes - Reversal curse
# --------------------------------------------------------
#
# 01:12 - 01:21
#
# ChatGPT's knowledge is often quite one-dimensional. You need to ask questions from certain angles for accurate answers.
#
# 14\. Idea 1: Why ChatGPT makes mistakes
# ---------------------------------------
#
# 01:21 - 01:45
#
# What about OpenAI's GPT-4o model? Let's ask, "How many words are in your response to this prompt?" It states, "There are 41 words in my response to this prompt". This is a prime example of hallucination where ChatGPT confidently states a wrong answer. ChatGPT wasn't trained to understand 'words' like humans. Instead, it focuses on language at the token level.
#
# 15\. Idea 1: Why ChatGPT makes mistakes
# ---------------------------------------
#
# 01:45 - 01:52
#
# What's the takeaway? To uncover the truth, we've got to understand how ChatGPT thinks.
#
# 16\. Idea 2: How ChatGPT thinks
# -------------------------------
#
# 01:52 - 02:03
#
# We must remember ChatGPT's function. ChatGPT predicts the next word based on the previous sequence. It's a next-word prediction tool, trained to be conversational.
#
# 17\. Idea 2: How ChatGPT thinks
# -------------------------------
#
# 02:03 - 02:23
#
# System 1 versus System 2 thinking was popularised by the book 'Thinking, Fast and Slow' by Daniel Kahneman. System 1 thinking is fast, instinctive, and automatic, whereas system 2 thinking is slow, rational and conscious.
#
# 18\. Idea 2: How ChatGPT thinks
# -------------------------------
#
# 02:23 - 02:36
#
# Why is this relevant to how ChatGPT thinks? Well, LLMs today are only capable of System 1 thinking, imitating human responses. It's hard to go above human response accuracy if LLMs are only trained on humans.
#
# 19\. Idea 2: How ChatGPT thinks
# -------------------------------
#
# 02:36 - 02:50
#
# Models generate words like laying train tracks in front of them. What could it mean to give language models System 2 thinking? This remains a future development I'm excited about and sparks thoughts about where ChatGPT might be heading.
#
# 20\. Idea 3: Where ChatGPT is heading
# -------------------------------------
#
# 02:50 - 03:11
#
# In May 2024, OpenAI partnered with Be My Eyes, aiding people with blindness through GPT-4o's multimodality. As the AI sees through the camera and speaks, Andy builds a visual image and can fully appreciate what's in front of him. This is the next level up from traditional LLMs, which just process text.
#
# 21\. Idea 3: Where ChatGPT is heading
# -------------------------------------
#
# 03:11 - 03:29
#
# The example with Be My Eyes is a spectacular and very real step towards a much more natural human-computer interface. ChatGPT will soon be integrated into our phones, computers, and, at some point, with the recent advancements of brain-computer interfaces like Neuralink, our minds.
#
# 22\. Idea 3: Where ChatGPT is heading
# -------------------------------------
#
# 03:29 - 03:49
#
# Extrapolating ChatGPT's progress forward means we must respect the outcome that hovers over our shoulders when we eventually reach artificial general intelligence---a system capable of producing the same output as a human knowledge worker. There are three key questions that are important for humanity to address.
#
# 23\. Idea 3: Where ChatGPT is heading
# -------------------------------------
#
# 03:49 - 04:05
#
# How do we share wealth? How does access to these systems work? Who decides what we get to use these systems for? How we think about a world like this is not yet obvious. Answering these questions will define humanity in the years to come.
#
# 24\. Congratulations!
# ---------------------
#
# 04:05 - 04:16
#
# Congratulations. You've nailed this course, and you should be proud of how far you've come. After all, there are only two things left to do.
#
# 25\. Congratulations!
# ---------------------
#
# 04:16 - 04:22
#
# First, use your newfound knowledge to create something meaningful to you with ChatGPT.
#
# 26\. Congratulations!
# ---------------------
#
# 04:22 - 04:28
#
# Second, wow your friends at the dinner table with your new ChatGPT knowledge.
#
# 27\. Thanks!
# ------------
#
# 04:28 - 04:35
#
# Thank you for joining me on Intermediate ChatGPT, and I'll see you very soon.
